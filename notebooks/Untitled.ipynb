# %%
# Confusion Matrix
tn, fp, fn, tp = confusion_matrix(y_test, y_pred_test_weighted).ravel()

# Extract False Positive Records
false_positives = x_test[(y_pred_test_weighted == 1) & (y_test == 0)]

# Driving Factors: Feature Importance
coefficients = pd.DataFrame({
    'Feature': X.columns,
    'Coefficient': lg_weighted.coef_[0]
}).sort_values(by='Coefficient', ascending=False)

print("False Positive Records:")
print(false_positives)

print("\nDriving Factors (Feature Coefficients):")
print(coefficients)
# Out:
# Fitting 3 folds for each of 15 candidates, totalling 45 fits
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_scorer.py:610: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(
# Best Parameters: {'C': 0.1, 'class_weight': {0: 1, 1: 3}}
# Best Revenue: nan
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/opt/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 279, in __call__
# ...
